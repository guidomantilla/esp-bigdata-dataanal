# %% [markdown]
# # Python for Data Analysis
#
# * Profesor: Alvaro Javier Cangrejo

# %% [markdown]
# - Documentación oficial
#  - Python: https://docs.python.org/3/
#  - NumPy: https://docs.scipy.org/doc/
#  - pandas: https://pandas.pydata.org/index.html
#  - matplotlib: https://matplotlib.org/

# %% [markdown]
# ![ejemplo8.png](data:image/png;base64,...)

# %% [markdown]
# ## Data types and operators

# %% [markdown]
# Operadores aritmeticos
#
# $+$ : suma \\
# $-$ : sustracción \\
# $*$ : multiplicación \\
# $/$ : división \\
# $\%$ : modulo(el resto depués de dividir) \\
# $**$ : Exponenciación (tenga encuenta que ^ no realiza está operación) \\
# $//$ : Divide y redonde hacia abajo hasta el número entero más cercano
#
# #### Operatores aritméticos
#
# | Operador | Desc |
# |:---------|:-----|
# | a + b    | Suma |
# | a - b    | Resta |
# | a / b    | División |
# | a // b   | División Entera |
# | a % b    | Modulo / Resto |
# | a * b    | Multiplicacion |
# | a ** b   | Exponenciación |

# %%
2 + 3
# Out:
# 5

# %%
print(2 + 3)
# Out:
# 5

# %%
print((17 - 6) % (5 + 2))
# Out:
# 4

# %%
avg = (23 + 32 + 64) / 3
print(avg)
# Out:
# 39.666666666666664

# %%
x = 3
y = 2

print("x + y = ", x + y)
print("x - y = ", x - y)
print("x * y = ", x * y)
print("x / y = ", x / y)
print("x // y = ", x // y)
print("x % y = ", x % y)
print("x ** y = ", x**y)

# %% [markdown]
# Varibles y operadores

# %%
mv_population = 74728

# %%
## Haga esto

my_lat = 40
my_long = 105

## No haga esto

my lat = 40
my long = 105

# %% [markdown]
#  Operadores de asignación
#
#  | Simbolo| Ejemplo  | Equialencia|
#  |-----| ----- | ----- |
#  | =| x = 2 | x = 2 |
#  |+=| x+=2 | x = x+2 |
#  |-=| x-=2 | x = x-2 |

# %% [markdown]
# Numero enteros y flotantes![ejemplo9.png](data:image/png;base64,...)

# %%
x = int(4.7)
y = float(4)

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(int(49.5))
# Out:
# 49

# %%
print(0.1 + 0.1 + 0.1 == 0.3)
# Out:
# False

# %% [markdown]
# **Operadores Booleanos** (True, False).
#
# **Operadore comparación**
#
# | Simbolo | operacion |
# |--- | --- |
# |< | menor |
# |> | mayor |
# | <= | menor-igual|
# | >= | mayor-igual|
# | == | igual |
# |!=| diferente|
#
#
# #### Operadores Lógicos
#
#
# | Operador | Desc |
# |:---------|:-----|
# | a and b  | True, si ambos son True |
# | a or b   | True, si alguno de los dos es True |
# | a ^ b   | XOR - True, si solo uno de los dos es True |
# | not a    | Negación |

# %%
x = 42 > 43
print(x)
# Out:
# False

# %%
age = 24
is_teen = age > 12 and age < 30
print(is_teen)
# Out:
# True

# %%
not_teen = not (age > 12 and age < 30)
print(not_teen)
# Out:
# False

# %%
x = 10
y = 12

print("x > y  es ", x > y)
print("x < y  es ", x < y)
print("x == y es ", x == y)
print("x != y es ", x != y)
print("x >= y es ", x >= y)
print("x <= y es ", x <= y)

# %%
x = True
y = False

print("x and y es :", x and y)
print("x or y es  :", x or y)
print("x or y es  :", x ^ y)
print("not x es   :", not x)

# %% [markdown]
# **Strings**

# %%
string_1 = "Curso data analytics"
string_2 = "Profesor alvaro"
print(string_1 + " " + string_2)
# Out:
# Curso data analytics Profesor alvaro

# %%
print(string_1 * 5)
# Out:
# Curso data analyticsCurso data analyticsCurso data analyticsCurso data analyticsCurso data analytics

# %%
print(len(string_1))
# Out:
# 20

# %%
string_1 / string_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-9e3b43190e08> in <cell line: 0>()
# ----> 1 string_1 / string_2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# **Type and type conversion**
#
#
#
# * int
# * float
# * bool
# * string

# %%
print(type(633))
print(type("633"))
print(type(633.0))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
numero_calle = 13
nombre_calle = "The Crescent"
nombre_ciudad = "Belmont"
print(type(numero_calle))
# Out:
# <class 'int'>

# %%
direccion = str(numero_calle) + " " + nombre_calle + ", " + nombre_ciudad
print(direccion)
# Out:
# 13 The Crescent, Belmont

# %%
w = "35.0"
print(type(w))
w = float(w)
print(type(w))
# Out:
# <class 'str'>
# <class 'float'>

# %% [markdown]
# **String Methods (metodos cadenas)**
#
# Un metodo en ptyhon se comporta de manera similar a una función. Los métodos en realidad son funciones que se llaman mediante notación de puntos.
#
# ![ejemplo12.png](data:image/png;base64,...)

# %%
my_string = "Profesor alvaro cangrejo"
my_string.islower()  ## islower() determina si los caracteres alfabéticos en la cadena están en minúsculas
my_string.count("a")  ## conteo numero de apariciones
my_string.find("a")  ## busca posición de la primera aparición
# Out:
# 9

# %%
## Metodo :: format() ---> permitiendo insertar valores en posiciones específicas dentro de una cadena de texto.

print(
    "La universidad del bosque se encuetra entre las {} mejores universidades de colombia".format(
        10
    )
)

t = "mejor"
r = "curso"

print("Data analytics es el {} {} de la universidad".format(t, r))
# Out:
# La universidad del bosque se encuetra entre las 10 mejores universidades de colombia
# Data analytics es el mejor curso de la universidad

# %% [markdown]
# #### Alias/Referencias en las listas
# - Son mutables y las asignaciones a un objeto alteran el primero
# - Pasar listas a funciones puede suponer un riesgo
# - Clonar o copiar listas

# %%
lista = [2, 4, 16, 32]
ref = lista

ref[2] = 64

print(ref)
print(lista)

# %%
lista = [2, 4, 16, 32]
copia = lista[:]
# copia = lista.copy()

copia[2] = 64

print(lista)
print(copia)
# Out:
# [2, 4, 16, 32]
# [2, 4, 64, 32]

# %%
# listas anidadas se copian por referencia
lista = [2, 4, 16, 32, [34, 10, [5, 5]]]
copia = lista.copy()

copia[4][0] = 28

print(copia)
print(lista)

# %%
# evitar que listas anidadas se copien por referencia
import copy

lista = [2, 4, 16, 32, [34, 10, [5, 5]]]

copia = copy.deepcopy(lista)
copia[0] = 454
copia[4][2][0] = 64
print(lista)
print(copia)

# %% [markdown]
# #### Operaciones con diccionarios
#
# * Creación de diccionarios.

# %%
# Creación simple, usando una expresión literal.

persona = {"DNI": "11111111D", "Nombre": "Carlos", "Edad": 34}
print(persona)
# Out:
# {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}

# %%
# Creación uniendo dos colecciones.

nombres = ["Pablo", "Manolo", "Pepe", "Juan"]
edades = [52, 14, 65]

datos = dict(zip(nombres, edades))
print(datos)
# Out:
# {'Pablo': 52, 'Manolo': 14, 'Pepe': 65}

# %% [markdown]
# ## Control flow (sentencias de control)

# %%
## Declaraciones condicionales

if n % 2 == 0:
    print("numer" + str(n) + " es par.")
else:
    print("numer" + str(n) + "es impar.")

# %%
## Caso 1

n = 4

if n % 2 == 0:
    print("numer" + str(n) + " es par.")
else:
    print("numer" + str(n) + "es impar.")
# Out:
# numer4 es par.

# %%
## Caso 2

n = 17

if n % 2 == 0:
    print("numer" + str(n) + " es par.")
else:
    print("numer" + str(n) + "es impar.")
# Out:
# numer17es impar.

# %%
# nota: Este código usa una estructura if-elif-else para tomar una acción diferente dependiendo de la estación del año almacenada en la variable temporada.

temporada = ""
if temporada == "primavera":
    print("¡Planta el jardín!")
elif temporada == "verano":
    print("¡Riega el jardín!")
elif temporada == "otoño":
    print("¡Cosecha el jardín!")
elif temporada == "invierno":
    print("¡Quédate en casa!")
else:
    print("Temporada no reconocida")
# Out:
# Temporada no reconocida

# %% [markdown]
# * Anidaiento

# %%
val = 120
if val > 0:
    if val < 100:
        print("Valor positivo")
    else:
        print("Valor muy positivo")
else:
    print("Valor negativo")
# Out:
# Valor muy positivo

# %% [markdown]
# **Ejercicio en clase**
#
# Escriba una declaración *if* que el permita a un competidor saber cual de estos premios gnó en función de la cantidad de puntos que obtuvo
#
# | Puntos | Premios |
# | --- | --- |
# | 1-50 | conejo madera |
# |51-150 | sin premio |
# | 151-180 | oblea |
# | 181 - 200 | pinguino |

# %%
## Bucles for and while

cities = ["new york city", "mountain view", "chicago", "los angeles"]

for city in cities:
    print(city.title())
# Out:
# New York City
# Mountain View
# Chicago
# Los Angeles

# %%
cities = ["new york city", "mountain view", "chicago", "los angeles"]

capitalized_cities = []

for city in cities:
    capitalized_cities.append(city.title())
# Out:
# ['New York City', 'Mountain View', 'Chicago', 'Los Angeles']

# %%
print(list(range(4)))
# Out:
# [0, 1, 2, 3]

# %%
for index in range(len(cities)):
    cities[index] = cities[index].title()
    print(cities)

# %% [markdown]
# #### Bucle 'while'
#
# * Repetición de un bloque de código hasta que se deje cumplir una expresión (es decir, hasta que una condición evalue a *False*).
# * Si la condición evalua a *False* desde el principio, el bloque de código nunca se ejecuta.
# * Cuidado con los bucles infinitos.
#
# Formato general:
#
# ```
# while test:       # Mientras se cumple la condición
#     statements    # Instrucciones a ejecutar
# ```

# %%
# Ejemplo: Mostrar los primeros 3 objetos de una lista

indice = 0
numeros = [9, 4, 7, 1, 2]

while indice < 3:
    print(numeros[indice])
    indice += 1
# Out:
# 9
# 4
# 7

# %%
# Ejemplo: contar y mostrar los números inferiores a 10.

numeros = [33, 3, 9, 21, 1, 7, 12, 10, 8]
contador = 0
indice = 0

while indice < len(numeros):
    if numeros[indice] < 10:
        print(numeros[indice])
        contador += 1
    indice += 1

print("Contador:", contador)
print("Indice:", indice)
# Out:
# 3
# 9
# 1
# 7
# 8
# Contador: 5
# Indice: 9

# %% [markdown]
# ## Functions

# %% [markdown]
# ## ¿Qué son?
#
# * Son un mecanismo que te ofrece el lenguaje para agrupar conjuntos de instrucciones de manera que se puedan ejecutar cuando el programador considere oportuno.
# * Las funciones van identificadas por un nombre.
# * Se debe usar este nombre para invocar (ejecutar) el código de la función.
# * Las funciones calculan un resultado (output) en base a unos parámetros de entrada (input).
# * En cada invocación de la función, los parámetros de entrada pueden variar.

# %%
def sumar(x, y):
    return x + y


print(sumar(4, 5))
print(sumar(-2, 0))
# Out:
# 9
# -2

# %%
# f = c × 1.793 + 32

c = 30
print(c * 1.793 + 32)  # celsius to fahren

c = 26
print(c * 1.793 + 32)
# Out:
# 85.78999999999999
# 78.618

# %%
def convert_celsius_to_fahrenheit(c):
    return c * 1.791117 + 32

# %%
degrees = 30
print(convert_celsius_to_fahrenheit(degrees))
# Out:
# 85.73351

# %% [markdown]
# ## ¿Qué ventajas nos proporcionan?
#
# * Eliminación de duplicación de código.
# * Incremento de la reutilización de código.
# * Manejo de complejidad: permiten descomponer grandes sistemas en piezas más pequeñas y, por tanto, más manejables y comprensibles.

# %% [markdown]
# Las funciones se definen por medio de la palabra clave *def*.
#
# Formato general:
#
# ```
# def name(arg1, arg2, ..., argN):
#     statements
# ```
#
# Muy comúnmente:
#
# ```
# def name(arg1, arg2, ..., argN):
#     ...
#     return value
# ```

# %%
def div_safe(x, y):
    if y == 0:
        return 0
    return x // y


print(div_safe(6, 2))
print(div_safe(6, 0))
# Out:
# 3
# 0

# %%
def div_safe(x, y):
    if y != 0:
        return x // y
    else:
        return 0


print(div_safe(6, 2))
# Out:
# 3

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(datos, color, d):
    """
    Función que calcula estadísticas básicas y grafica un histograma.

    :param datos: Lista o array de datos numéricos.
    :param color: Color del histograma.
    :param d: Cantidad de decimales en los resultados.
    :return: Lista con [mediana, promedio, mínimo, máximo]
    """
    # 1. Calcular valores estadísticos
    mediana = round(np.median(datos), d)
    promedio = round(np.mean(datos), d)
    minimo = round(np.min(datos), d)
    maximo = round(np.max(datos), d)

    # 2. Graficar histograma
    plt.figure()  # Crea una nueva ventana de figura
    plt.hist(
        datos, color=color, edgecolor="black", alpha=0.7
    )  # Histograma con bordes negros y transparencia
    plt.title("Histograma de Datos")
    plt.xlabel("Valores")
    plt.ylabel("Frecuencia")
    plt.grid(True, linestyle="--", alpha=0.5)  # Cuadrícula tenue
    plt.show()

    # 3. Retornar resultados
    return [mediana, promedio, minimo, maximo]


# Ejemplo de uso
x = np.random.randn(100)  # Simulación de datos aleatorios
resultado = f(x, "blue", 3)
print("Mediana, Promedio, Mínimo, Máximo:", resultado)
# Out:
# Mediana, Promedio, Mínimo, Máximo: [0.035, 0.153, -1.83, 3.016]

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 1. Escribe un programa que muestre por pantalla la concatenación de un número y una cadena de caracteres. Para obtener esta concatenación puedes usar uno de los operadores explicados en este tema. Ejemplo: dado el número 3 y la cadena 'abc', el programa mostrará la cadena '3abc'.
#
# 2. Escribe un programa que muestre por pantalla un valor booleano que indique si un número entero *N* está contenido en un intervalo semiabierto *[a,b)*, el cual establece una cota inferior *a* (inclusive) y una cota superior *b* (exclusive) para *N*.
#
# 3. Dada la lista [1,2,3,4,5,6,7,8] escribe un programa que, a partir de esta lista, obtenga la lista [8,6,4,2] y la muestre por pantalla.
#
# 4. Escribe un programa que, dada una tupla y un índice válido *i*, elimine el elemento de la tupla que se encuentra en la posición *i*. Para este ejercicio sólo puedes usar objetos de tipo tupla. No puedes convetir la *tupla* a una *lista*, por ejemplo.
#
# 5. Escribe un programa que obtenga la mediana de una *lista* de números. Recuerda que la mediana *M* de una lista de números *L* es el número que cumple la siguiente propiedad: la mitad de los números de *L* son superiores a *M* y la otra mitad son inferiores. Cuando el número de elementos de *L* es par, se puede considerar que hay dos medianas. No obstante, en este ejercicio consideraremos que únicamente existe una mediana.
#
# 6. Escribe un programa que calcule la suma de todos los elementos de una *lista* dada. La lista sólo puede contener elementos numéricos.
#
# 7. Dada una lista con elementos duplicados, escribir un programa que muestre una nueva lista con el mismo contenido que la primera pero sin elementos duplicados. Para este ejercicio, no puedes hacer uso de objetos de tipo 'Set'.
#
# 8. Escribe un programa que construya un diccionario que contenga un número (entre 1 y *n*) de elementos de esta forma: (x, x*x). Ejemplo: para n = 5, el diccionario resultante sería {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
#
# 9. Escribe un programa que, dada una lista de palabras, compruebe si alguna empieza por 'a' y tiene más de 9 caracteres. Si dicha palabra existe, el programa deberá terminar en el momento exacto de encontrarla. El programa también debe mostrar un mensaje apropiado por pantalla que indique el éxito o el fracaso de la búsqueda. En caso de éxito, también se mostrará por pantalla la palabra encontrada.
#
# 10. Dada una lista *L* de números positivos, escribir un programa que muestre otra lista (ordenada) que contenga todo índice *i* que cumpla la siguiente condición: *L[i]* es múltiplo de 3. Por ejemplo, dada la lista *L* = [3,5,13,12,1,9] el programa mostrará la lista [0,3,5] dado que *L[0], L[3] y L[5]* son, respectivamente, 3, 12 y 9, que son los únicos múltiplos de 3 que hay en *L*.
#
# 11. Dado un diccionario cuyos elementos son pares de tipo string y numérico (es decir, las claves son de tipo 'str' y los valores son de tipo 'int' o 'float'), escribe un programa que muestre por pantalla la clave cuyo valor asociado representa el valor númerico más alto de todo el diccionario. Por ejemplo, para el diccionario {'a': 4.3, 'b': 1, 'c': 7.8, 'd': -5} la respuesta sería 'c', dado que 7.8 es el valor más alto de los números 4.3, 1, 7.8 y -5.
#
# 12. Dada la lista *a* = [2, 4, 6, 8] y la lista *b* = [7, 11, 15, 22], escribe un programa que itere las listas *a* y *b* y multiplique cada elemento de *a* que sea mayor que 5 por cada elemento de *b* que sea menor que 14. El programa debe mostrar los resultados por pantalla.
#
# 13. Escribir un programa que pida un valor numérico X al usuario. Para ello podéis hacer uso de la función predefinida 'input'. El programa deberá mostrar por pantalla el resultado de la división 10/X. En caso de que el usuario introduzca valores no apropiados, el programa deberá gestionar correctamente las excepciones, por ejemplo, mostrando mensajes informativos por pantalla.
#
# 14. Escribir un programa que cree un *diccionario* cualquiera. Posteriormente, el programa pedirá al usuario (a través de la función predefinida 'input') que introduzca una clave del diccionario. Si la clave introducida es correcta (es decir, existe en el diccionario), el programa mostrará por pantalla el valor asociado a dicha clave. En caso de que la clave no exista, el programa gestionará de manera apropiada el error, por ejemplo, mostrando un mensaje informativo al usuario.
#
# 15. Escribe una *list comprehension* que construya una lista con los números *enteros* positivos de una lista de números dada. La lista original puede incluir números de tipo *float*, los cuales deben ser descartados.
#
# 16. Escribe una *set comprehension* que, dada una palabra, construya un conjunto que contenga las vocales de dicha palabra.
#
# 17. Escribe una función que reciba como entrada una *lista* con números y devuelva como resultado una *lista* con los cuadrados de los números contenidos en la lista de entrada.
#
# 18. Escribe una función que reciba números como entrada y devuelva la suma de los mismos. La función debe ser capaz de recibir una cantidad indeterminada de números. La función no debe recibir directamente ningún objeto complejo (lista, conjunto, etc.).
#
# 19. Escribe una función que reciba un número entero positivo como parámetro y devuelva una lista que contenga los 5 primeros múltiplos de dicho número. Por ejemplo, si la función recibe el número 3, devolverá la lista [3, 6, 9, 12, 15]. Si la función recibe un parámetro incorrecto (por ejemplo, un múmero menor o igual a cero), mostrará un mensaje de error por pantalla y devolverá una lista vacía.
#
# 20. Escribe una función que reciba una lista como parámetro y compruebe si la lista tiene duplicados. La función devolverá *True* si la lista tiene duplicados y *False* si no los tiene.
