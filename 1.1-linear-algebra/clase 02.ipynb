# %% [markdown]
# # Programacion Lineal
#
# ## Desigualdades
# ![](resources/img08.png)

# %% [markdown]
# ### 1.
# Resuelva la siguiente desigualdad: 2x + 3y > 6

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "2x + 3y > 6", 2 * x + 3 * y, 6
print_solution_inequality(label, x, y, expression, ">", result)
# Out:
# Solución de la desigualdad:
# $$x = \left(3 - \frac{3 y}{2}, \infty\right)$$
# $$y = \left(2 - \frac{2 x}{3}, \infty\right)$$

# %% [markdown]
# ### 2.
# Resuelva la siguiente desigualdad: 3x - 2y >= 12

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "3x - 2y >= 12", 3 * x - 2 * y, 12
print_solution_inequality(label, x, y, expression, ">=", result, False)
# Out:
# Solución de la desigualdad:
# $$x = \left[\frac{2 y}{3} + 4, \infty\right)$$
# $$y = \left(-\infty, \frac{3 x}{2} - 6\right]$$

# %% [markdown]
# ### 3.
# Resuelva la siguiente desigualdad: x + 2y <= 7

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "x + 2y <= 7", x + 2 * y, 7
print_solution_inequality(label, x, y, expression, "<=", result, False)
# Out:
# Solución de la desigualdad:
# $$x = \left(-\infty, 7 - 2 y\right]$$
# $$y = \left(-\infty, \frac{7}{2} - \frac{x}{2}\right]$$

# %% [markdown]
# ### 4.
# Resuelva la siguiente desigualdad: y > 6 -2x

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "y > 6 -2x", y, 6 - 2 * x
print_solution_inequality(label, x, y, expression, ">", result)
# Out:
# Solución de la desigualdad:
# $$x = \left(3 - \frac{y}{2}, \infty\right)$$
# $$y = \left(6 - 2 x, \infty\right)$$

# %% [markdown]
# ### 5.
# Resuelva la siguiente desigualdad: -x <= 2y -4

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "-x <= 2y -4", -x, 2 * y - 4
print_solution_inequality(label, x, y, expression, "<=", result)
# Out:
# Solución de la desigualdad:
# $$x = \left[4 - 2 y, \infty\right)$$
# $$y = \left[2 - \frac{x}{2}, \infty\right)$$

# %% [markdown]
# ### 6.
# Resuelva la siguiente desigualdad: 2x + y >= 10

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "2x + y >= 10", 2 * x + y, 10
print_solution_inequality(label, x, y, expression, ">=", result)
# Out:
# Solución de la desigualdad:
# $$x = \left[5 - \frac{y}{2}, \infty\right)$$
# $$y = \left[10 - 2 x, \infty\right)$$

# %% [markdown]
# ### 7.
# Resuelva la siguiente desigualdad: 3x + y < 0

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "3x + y < 0", 3 * x + y, 0
print_solution_inequality(label, x, y, expression, "<", result, False)
# Out:
# Solución de la desigualdad:
# $$x = \left(-\infty, - \frac{y}{3}\right)$$
# $$y = \left(-\infty, - 3 x\right)$$

# %% [markdown]
# ### 8.
# Resuelva la siguiente desigualdad: x + 5y < -5

# %%
import sympy as sp
from pkg.functions import print_solution_inequality

x, y = sp.symbols("x y", real=True)
label, expression, result = "x + 5y < -5", x + 5 * y, -5
print_solution_inequality(label, x, y, expression, "<", result, False)
# Out:
# Solución de la desigualdad:
# $$x = \left(-\infty, - 5 y - 5\right)$$
# $$y = \left(-\infty, - \frac{x}{5} - 1\right)$$
