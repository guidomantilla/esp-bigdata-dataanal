# %% [markdown]
# # Programacion Lineal

# %% [markdown]
# ## Desigualdades (1 - 8)
# ![](resources/img08.png)

# %% [markdown]
# ### 1.
# Resuelva la siguiente desigualdad: 2x + 3y > 6

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(2 * x + 3 * y, 6, ">")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: 2*x + 3*y > 6
# $$x = \left(3 - \frac{3 y}{2}, \infty\right)$$
# $$y = \left(2 - \frac{2 x}{3}, \infty\right)$$
# y > 2 - 2*x/3 {x, y}
# [2 - 2*x/3]

# %% [markdown]
# ### 2.
# Resuelva la siguiente desigualdad: 3x - 2y >= 12

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(3 * x - 2 * y, 12, ">=")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: 3*x - 2*y >= 12
# $$x = \left[\frac{2 y}{3} + 4, \infty\right)$$
# $$y = \left(-\infty, \frac{3 x}{2} - 6\right]$$
# y <= 3*x/2 - 6 {x, y}
# [3*x/2 - 6]

# %% [markdown]
# ### 3.
# Resuelva la siguiente desigualdad: x + 2y <= 7

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(x + 2 * y, 7, "<=")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: x + 2*y <= 7
# $$x = \left(-\infty, 7 - 2 y\right]$$
# $$y = \left(-\infty, \frac{7}{2} - \frac{x}{2}\right]$$
# y <= 7/2 - x/2 {x, y}
# [7/2 - x/2]

# %% [markdown]
# ### 4.
# Resuelva la siguiente desigualdad: y > 6 -2x

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(y, 6 - 2 * x, ">")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: y > 6 - 2*x
# $$x = \left(3 - \frac{y}{2}, \infty\right)$$
# $$y = \left(6 - 2 x, \infty\right)$$
# y > 6 - 2*x {x, y}
# [6 - 2*x]

# %% [markdown]
# ### 5.
# Resuelva la siguiente desigualdad: -x <= 2y -4

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(-x, 2 * y - 4, "<=")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: -x <= 2*y - 4
# $$x = \left[4 - 2 y, \infty\right)$$
# $$y = \left[2 - \frac{x}{2}, \infty\right)$$
# y >= 2 - x/2 {x, y}
# [2 - x/2]

# %% [markdown]
# ### 6.
# Resuelva la siguiente desigualdad: 2x + y >= 10

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(2 * x + y, 10, ">=")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: 2*x + y >= 10
# $$x = \left[5 - \frac{y}{2}, \infty\right)$$
# $$y = \left[10 - 2 x, \infty\right)$$
# y >= 10 - 2*x {x, y}
# [10 - 2*x]

# %% [markdown]
# ### 7.
# Resuelva la siguiente desigualdad: 3x + y < 0

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(3 * x + y, 0, "<")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: 3*x + y < 0
# $$x = \left(-\infty, - \frac{y}{3}\right)$$
# $$y = \left(-\infty, - 3 x\right)$$
# y < -3*x {x, y}
# [-3*x]

# %% [markdown]
# ### 8.
# Resuelva la siguiente desigualdad: x + 5y < -5

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
)

x, y = sp.symbols("x y", real=True)
equation = sp.Rel(x + 5 * y, -5, "<")
sol_x, sol_y = calculate_solution_equation(x, y, equation)
print_solution_equation(x, y, equation, sol_x, sol_y)
plot = plot_solution_equation(x, y, equation)
plot.show()
# Out:
# Solución de la desigualdad: x + 5*y < -5
# $$x = \left(-\infty, - 5 y - 5\right)$$
# $$y = \left(-\infty, - \frac{x}{5} - 1\right)$$
# y < -x/5 - 1 {x, y}
# [-x/5 - 1]

# %% [markdown]
# ## Desigualdades (9 - 13) - continuacion
# ![](resources/img08.png)

# %% [markdown]
# ### 9:
# Resuelva las siguientes desigualdades:
#
#     3x - 2y < 6
#      x - 3y > 9

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(3 * x - 2 * y, 6, "<")
equation2 = sp.Rel(x - 3 * y, 9, ">")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: 3*x - 2*y < 6
# $$x = \left(-\infty, \frac{2 y}{3} + 2\right)$$
# $$y = \left(\frac{3 x}{2} - 3, \infty\right)$$
# y > 3*x/2 - 3 {x, y}
# [3*x/2 - 3]
# Solución de la desigualdad: x - 3*y > 9
# $$x = \left(3 y + 9, \infty\right)$$
# $$y = \left(-\infty, \frac{x}{3} - 3\right)$$
# y < x/3 - 3 {x, y}
# [x/3 - 3]
# y > 3*x/2 - 3 {x, y}
# y < x/3 - 3 {x, y}
# [3*x/2 - 3, x/3 - 3]

# %% [markdown]
# ### 10:
# Resuelva las siguientes desigualdades:
#
#     2x + 3y > -6
#     3x -  y < 6

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(2 * x + 3 * y, -6, ">")
equation2 = sp.Rel(3 * x - y, 6, "<")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: 2*x + 3*y > -6
# $$x = \left(- \frac{3 y}{2} - 3, \infty\right)$$
# $$y = \left(- \frac{2 x}{3} - 2, \infty\right)$$
# y > -2*x/3 - 2 {x, y}
# [-2*x/3 - 2]
# Solución de la desigualdad: 3*x - y < 6
# $$x = \left(-\infty, \frac{y}{3} + 2\right)$$
# $$y = \left(3 x - 6, \infty\right)$$
# y > 3*x - 6 {x, y}
# [3*x - 6]
# y > -2*x/3 - 2 {x, y}
# y > 3*x - 6 {x, y}
# [-2*x/3 - 2, 3*x - 6]

# %% [markdown]
# ### 11:
# Resuelva las siguientes desigualdades:
#
#     2x + 3y <= 6
#      x - 0y >= 0

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(2 * x + 3 * y, 6, "<=")
equation2 = sp.Rel(x - 0 * y, 0, ">=")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: 2*x + 3*y <= 6
# $$x = \left(-\infty, 3 - \frac{3 y}{2}\right]$$
# $$y = \left(-\infty, 2 - \frac{2 x}{3}\right]$$
# y <= 2 - 2*x/3 {x, y}
# [2 - 2*x/3]
# Solución de la desigualdad: x >= 0
# $$x = \left[0, \infty\right)$$
# $$y = \emptyset$$
# 0 <= x {x}
# [x]
# y <= 2 - 2*x/3 {x, y}
# 0 <= x {x}
# [2 - 2*x/3, x]

# %% [markdown]
# ### 12:
# Resuelva las siguientes desigualdades:
#
#     -3x + 2y < 6
#       x - 0y < 0

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(-3 * x + 2 * y, 6, "<")
equation2 = sp.Rel(x - 0 * y, 0, "<")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: -3*x + 2*y < 6
# $$x = \left(\frac{2 y}{3} - 2, \infty\right)$$
# $$y = \left(-\infty, \frac{3 x}{2} + 3\right)$$
# y < 3*x/2 + 3 {x, y}
# [3*x/2 + 3]
# Solución de la desigualdad: x < 0
# $$x = \left(-\infty, 0\right)$$
# $$y = \emptyset$$
# x < 0 {x}
# [0]
# y < 3*x/2 + 3 {x, y}
# x < 0 {x}
# [3*x/2 + 3, 0]

# %% [markdown]
# ### 13:
# Resuelva las siguientes desigualdades:
#
#     -3x + y <  6
#       x - y > -3

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(-3 * x + y, 6, "<")
equation2 = sp.Rel(x - y, -3, ">")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: -3*x + y < 6
# $$x = \left(\frac{y}{3} - 2, \infty\right)$$
# $$y = \left(-\infty, 3 x + 6\right)$$
# y < 3*x + 6 {x, y}
# [3*x + 6]
# Solución de la desigualdad: x - y > -3
# $$x = \left(y - 3, \infty\right)$$
# $$y = \left(-\infty, x + 3\right)$$
# y < x + 3 {x, y}
# [x + 3]
# y < 3*x + 6 {x, y}
# y < x + 3 {x, y}
# [3*x + 6, x + 3]

# %% [markdown]
# ## Desigualdades (14 - 18) - continuacion
# ![](resources/img08.png)

# %% [markdown]
# ### 14:
# Resuelva las siguientes desigualdades:
#
#      x - y < 1
#     -x + y < 1

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(x - y, 1, "<")
equation2 = sp.Rel(-x + y, 1, "<")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: x - y < 1
# $$x = \left(-\infty, y + 1\right)$$
# $$y = \left(x - 1, \infty\right)$$
# y > x - 1 {x, y}
# [x - 1]
# Solución de la desigualdad: -x + y < 1
# $$x = \left(y - 1, \infty\right)$$
# $$y = \left(-\infty, x + 1\right)$$
# y < x + 1 {x, y}
# [x + 1]
# y > x - 1 {x, y}
# y < x + 1 {x, y}
# [x - 1, x + 1]

# %% [markdown]
# ### 15:
# Resuelva las siguientes desigualdades:
#
#      2x + 2 >= y
#      2x <= 3 -2y

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(2 * x + 2, y, ">=")
equation2 = sp.Rel(2 * x, 3 - 2 * y, "<=")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: 2*x + 2 >= y
# $$x = \left[\frac{y}{2} - 1, \infty\right)$$
# $$y = \left(-\infty, 2 x + 2\right]$$
# y <= 2*x + 2 {x, y}
# [2*x + 2]
# Solución de la desigualdad: 2*x <= 3 - 2*y
# $$x = \left(-\infty, \frac{3}{2} - y\right]$$
# $$y = \left(-\infty, \frac{3}{2} - x\right]$$
# y <= 3/2 - x {x, y}
# [3/2 - x]
# y <= 2*x + 2 {x, y}
# y <= 3/2 - x {x, y}
# [2*x + 2, 3/2 - x]

# %% [markdown]
# ### 16:
# Resuelva las siguientes desigualdades:
#
#      2y < 4x + 2
#       y < 2x + 1

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(2 * y, 4 * x + 2, "<")
equation2 = sp.Rel(y, 2 * x + 1, "<")
equations = [equation1, equation2]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: 2*y < 4*x + 2
# $$x = \left(\frac{y}{2} - \frac{1}{2}, \infty\right)$$
# $$y = \left(-\infty, 2 x + 1\right)$$
# y < 2*x + 1 {x, y}
# [2*x + 1]
# Solución de la desigualdad: y < 2*x + 1
# $$x = \left(\frac{y}{2} - \frac{1}{2}, \infty\right)$$
# $$y = \left(-\infty, 2 x + 1\right)$$
# y < 2*x + 1 {x, y}
# [2*x + 1]
# y < 2*x + 1 {x, y}
# y < 2*x + 1 {x, y}
# [2*x + 1, 2*x + 1]

# %% [markdown]
# ### 17:
# Resuelva las siguientes desigualdades:
#
#      x - y > 4
#      x < 2
#      y >-5

# %%
import sympy as sp
from pkg.functions import (
    calculate_solution_equation,
    print_solution_equation,
    plot_solution_equation,
    plot_solution_equations,
)

x, y = sp.symbols("x y", real=True)
equation1 = sp.Rel(x - y, 4, ">")
equation2 = sp.Rel(x, 2, "<")
equation3 = sp.Rel(y, -5, ">")
equations = [equation1, equation2, equation3]
for equation in equations:
    sol_x, sol_y = calculate_solution_equation(x, y, equation)
    print_solution_equation(x, y, equation, sol_x, sol_y)
    plot_solution_equation(x, y, equation)

plot = plot_solution_equations(x, y, equations)
plot.show()
# Out:
# Solución de la desigualdad: x - y > 4
# $$x = \left(y + 4, \infty\right)$$
# $$y = \left(-\infty, x - 4\right)$$
# y < x - 4 {x, y}
# [x - 4]
# Solución de la desigualdad: x < 2
# $$x = \left(-\infty, 2\right)$$
# $$y = \emptyset$$
# x < 2 {x}
# [2]
# Solución de la desigualdad: y > -5
# $$x = \emptyset$$
# $$y = \left(-5, \infty\right)$$
# -5 < y {y}
# [-5]
# y < x - 4 {x, y}
# x < 2 {x}
# -5 < y {y}
# [x - 4, 2, -5]
